# %% [markdown]
# ![image.png](attachment:a6b3f534-d48c-4061-994e-0d64fee1c71d.png)

# %% [markdown]
# ![image.png](attachment:bcebe9d1-4580-4fd2-a78b-8a2c6f810d97.png)
#
#     卷积->通道变大
#     池化->特称图变小

# %% [markdown]
# 展平操作（flatten）
#
# ![image.png](attachment:59db3f5a-ee9a-403f-a170-f99e279823eb.png)

# %% [markdown]
# ![image.png](attachment:b0cc27a6-d093-4154-aaab-a0760690a28e.png)

# %% [markdown]
#     LeNet5五层网络结构
#     LeNet（LeNet-5）由两个部分组成：
#     特征提取部分：由两个卷积层和两个平均池化层组成；（主干）model+提取
#     全连接层：由三个全连接层组成。
#
#     模型单元结构：
#     一个卷积层、一个sigmoid激活函数，一个池化层

# %% [markdown]
# ![image.png](attachment:b23f71d2-cad5-4cc3-add4-42c29eb49152.png)
#
#     B是批次，C是通道
#     卷积层输出的数据（B,FN,OH,OW）
#     全连接层的输入为（B,FN * OH * OW）

# %% [markdown]
#     处理数据+train训练 占工作的百分之八十
#     最后的model搭建占工作的百分之二十

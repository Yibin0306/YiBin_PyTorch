# %% [markdown]
# ![image.png](attachment:b1b9c965-00ec-42a2-a27f-6b776527f9c0.png)

# %% [markdown]
# ![image.png](attachment:8de7b7fe-b9a6-469e-948c-b70a57576acb.png)

# %% [markdown]
# ![image.png](attachment:7aa102fd-d324-4def-bc7f-5dd771adebeb.png)

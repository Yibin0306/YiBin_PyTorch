# %% [markdown]
# ![image.png](attachment:9251a6e1-6f5c-4979-ad6a-2082c493a52f.png)

# %% [markdown]
# ![image.png](attachment:ea10078a-19f1-4205-b2de-65b14e985bcf.png)

# %% [markdown]
# 归一化是为了让网络各层的输入数据分布稳定，从而加速训练并提高稳定性。

# %% [markdown]
# ![image.png](attachment:d9814060-6e8d-4064-aa64-1707cf68e638.png)

# %% [markdown]
# ![image.png](attachment:3ba6f8a7-6511-4d2d-a1bf-0da1bed155bc.png)

# %% [markdown]
# ![image.png](attachment:bca53128-06c5-4d1d-a357-9f8fdb68a619.png)

# %% [markdown]
# ![image.png](attachment:4d804f91-2b52-4fb6-afc2-96436ff90045.png)

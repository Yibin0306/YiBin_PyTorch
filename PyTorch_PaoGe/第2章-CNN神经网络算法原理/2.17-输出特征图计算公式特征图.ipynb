# %% [markdown]
#     给大家一个我自己公式理解参考：输出特征图尺寸 = 卷积核移动次数 + 1(+1源于开始没移动)，
#     卷积核移动次数 = 输入特征图尺寸 - 卷积核尺寸 + 2Padding
# ![image.png](attachment:1e078a27-8b70-498a-8411-0012765d3cf7.png)

# %% [markdown]
# ![image.png](attachment:3bbfca06-bd0e-4be3-a7d6-c1a3c9e53d7b.png)
# ![image.png](attachment:832455d3-9851-4e2d-89e6-8d822ed71a5d.png)
# 总的测量位置次数= 移动的次数+ 最初的1次。

# %% [markdown]
# OH和OW算出来如果是小数，在pytorch中向下取整

# %% [markdown]
#  ![image.png](attachment:ba645e31-9b05-4222-b7de-1a0a471d90a8.png)

# %% [markdown]
# ![image.png](attachment:3055e36c-b888-4ba0-871d-b3e98b688b55.png)
# ![image.png](attachment:7d97b372-bc0e-418e-a099-74fa194708d3.png)

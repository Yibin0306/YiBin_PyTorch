# %% [markdown]
# ![image.png](attachment:233cc4aa-c310-40f9-810b-9920374ad888.png)

# %% [markdown]
# ![image.png](attachment:7aaaf672-86fd-416d-b167-c7843df6e8c7.png)

# %% [markdown]
# ![image.png](attachment:0639c145-2dfa-4fa7-bd79-59cdde187ccf.png)

# %% [markdown]
# ![image.png](attachment:05ff8e80-463b-4aa8-b193-7d43edf6b2e5.png)

# %% [markdown]
# ![image.png](attachment:caa93ca5-3aa1-400d-b889-24cb1bdaed4b.png)

# %% [markdown]
# 总结：
# ![image.png](attachment:3fc24931-0346-428a-bf53-0657e8e4aced.png)
# ![image.png](attachment:f66beac6-97ca-4ef8-9fd0-ece44b183dd0.png)

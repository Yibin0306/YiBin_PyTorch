# %% [markdown]
# ![image.png](attachment:c94f57b9-943b-4288-a113-7abec46ba9f8.png)

# %% [markdown]
# ![image.png](attachment:454bfd89-3e98-4db2-a6cc-6470817209d2.png)

# %% [markdown]
# ![image.png](attachment:effd5a90-a254-4eae-a065-527791b729c7.png)

# %% [markdown]
# ![image.png](attachment:2334fa01-3bae-4f4b-a186-aa8cb68e497f.png)

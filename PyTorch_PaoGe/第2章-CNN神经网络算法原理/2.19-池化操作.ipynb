# %% [markdown]
# 池化的功能是是降低特征图的尺寸以减少计算量, 同时并保留主要特征
# ![image.png](attachment:1f1eae20-fe01-45f1-a103-ad6ca52b0848.png)

# %% [markdown]
# 相加除以4
# ![image.png](attachment:9fe26275-c272-43e5-9211-cf754e17bacb.png)

# %% [markdown]
# ![image.png](attachment:6c12f36c-038a-4dd0-a26c-ebd0154f9701.png)
